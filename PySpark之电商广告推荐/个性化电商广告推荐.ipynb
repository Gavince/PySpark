# %% [markdown]
# ### 个性化电商推荐

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import numpy as np
import pyspark
import os 
from pyspark import SparkConf
from pyspark.sql import SparkSession

# %%
# SPARK_APP_NAME = "Recomend goods"
# # SPARK_URL = 'spark://10.202.144.72:7070'
# config = (
#     ("spark.app.name", SPARK_APP_NAME),
#     ("spark.executor.memory", "4g"), # 设置该app启动时所占用的内存，默认1g
# #     ("spark.master", SPARK_URL),
#     ("spark.executor.cores", "1"), # 设置spark executor使用的CPU核心数
# )
# conf = SparkConf()
# conf.setAll(config)
spark = SparkSession.builder.appName("ceshi").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-23-2497aa33a220> in <module>()
#       9 # conf = SparkConf()
#      10 # conf.setAll(config)
# ---> 11 spark = SparkSession.builder.appName("ceshi").getOrCreate()
#
# ~/anaconda3/lib/python3.6/site-packages/pyspark/sql/session.py in getOrCreate(self)
#     184                             sparkConf.set(key, value)
#     185                         # This SparkContext may be an existing one.
# --> 186                         sc = SparkContext.getOrCreate(sparkConf)
#     187                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     188                     # by all sessions.
#
# ~/anaconda3/lib/python3.6/site-packages/pyspark/context.py in getOrCreate(cls, conf)
#     369         with SparkContext._lock:
#     370             if SparkContext._active_spark_context is None:
# ...

# %%
# reads  = pd.read_csv("./data/behavior_log.csv", chunksize=100, iterator=True)
# for i, read in enumerate(reads):
# #     if os.path.exist()
#     if i == 0:
#         read.to_csv("./data/small_behavior.csv", index=False)
#     elif i<1000:
# #         df = pd.read_csv("./data/small_behavior.csv")
#         read.to_csv("./data/small_behavior.csv", mode="a", index=False, header=False)
#     else:
#         break

# %%
df = pd.read_csv("./data/small_behavior.csv")
df.info()

# %%
adf = pd.read_csv("./data/ad_feature.csv")
adf.head()
# Out:
#    adgroup_id  cate_id  campaign_id  customer     brand   price
# 0       63133     6406        83237         1   95471.0  170.00
# 1      313401     6406        83237         1   87331.0  199.00
# 2      248909      392        83237         1   32233.0   38.00
# 3      208458      392        83237         1  174374.0  139.00
# 4      110847     7211       135256         2  145952.0   32.99

# %%
adf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846811 entries, 0 to 846810
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   adgroup_id   846811 non-null  int64
#  1   cate_id      846811 non-null  int64
#  2   campaign_id  846811 non-null  int64
#  3   customer     846811 non-null  int64
#  4   brand        600481 non-null  float64
#  5   price        846811 non-null  float64
# dtypes: float64(2), int64(4)
# memory usage: 38.8 MB

# %%
upf = pd.read_csv("./data/user_profile.csv")
upf.head()
# Out:
#    userid  cms_segid  cms_group_id  final_gender_code  age_level  \
# 0     234          0             5                  2          5
# 1     523          5             2                  2          2
# 2     612          0             8                  1          2
# 3    1670          0             4                  2          4
# 4    2545          0            10                  1          4
#
#    pvalue_level  shopping_level  occupation  new_user_class_level
# 0           NaN               3           0                    3.0
# 1           1.0               3           1                    2.0
# 2           2.0               3           0                    NaN
# 3           NaN               1           0                    NaN
# 4           NaN               3           0                    NaN

# %%
upf.head()
# Out:
#    userid  cms_segid  cms_group_id  final_gender_code  age_level  \
# 0     234          0             5                  2          5
# 1     523          5             2                  2          2
# 2     612          0             8                  1          2
# 3    1670          0             4                  2          4
# 4    2545          0            10                  1          4
#
#    pvalue_level  shopping_level  occupation  new_user_class_level
# 0           NaN               3           0                    3.0
# 1           1.0               3           1                    2.0
# 2           2.0               3           0                    NaN
# 3           NaN               1           0                    NaN
# 4           NaN               3           0                    NaN
